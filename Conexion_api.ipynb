# %% [markdown]
# ### 1.- CONEXIÓN A API
#
# - 1) Encontrar API del Coordinador Electrico Nacional de Chile. Acceder a página de desarrollador para registrarse y obtener un TOKEN para poder usar la API . [Link](https://portal.api.coordinador.cl/)
# - 2) Documentación APIs de medidas web PMRTE. Documentación y endpoints: [Link](https://portal.api.coordinador.cl/documentacion?service=medidas)

# %% [markdown]
# ### 2.- OBTENCIÓN DE MEDIDAS

# %%
#Importaciones 

import pandas as pd
import requests
import numpy as np

# %%
# API key
api_key = "b48f2cb8bb939f33a6defa95a26bf23a"

# %%
# Base URL for the API
url = "https://medidas.api.coordinador.cl:443/medidas-v2/measurement"

# Measure points and dates
measure_points = ['URIBE_023_PMGD2_UAS', 'TAMANGO_066_B1_IUN', 'RENGO_015_PMGD5_SLM', 'MALLOCO_012_PMGD5_PNF', 'CURICO_013_PMGD7_LCH']
dates = ['202405010000', '202406010000', '202407010000']

# Dictionary to store data by measure point
data_by_measure_point = {}

# Nested loop to iterate over measure points and dates
for measure_point in measure_points:
    # Initialize an empty dictionary for each measure point
    data_by_measure_point[measure_point] = {}
    
    for date in dates:
        params = {
            "channelId": "1,2,3,4",
            "measurePointId": measure_point,
            "period": date,
            "user_key": api_key
        }
        
        # Request data from the API
        response = requests.get(url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            print(f"Datos para {measure_point} en {date}:")
            # Store data in the nested dictionary with date as the key
            data_by_measure_point[measure_point][date] = data
        else:
            print(f"Error: {response.status_code}, {response.text} for {measure_point} on {date}")

# Example of how to access the data for a specific measure point and date
# datos_uribe_may = data_by_measure_point['URIBE_023_PMGD2_UAS']['202405010000']
# Out:
# Datos para URIBE_023_PMGD2_UAS en 202405010000:
# Datos para URIBE_023_PMGD2_UAS en 202406010000:
# Datos para URIBE_023_PMGD2_UAS en 202407010000:
# Datos para TAMANGO_066_B1_IUN en 202405010000:
# Datos para TAMANGO_066_B1_IUN en 202406010000:
# Datos para TAMANGO_066_B1_IUN en 202407010000:
# Datos para RENGO_015_PMGD5_SLM en 202405010000:
# Datos para RENGO_015_PMGD5_SLM en 202406010000:
# Datos para RENGO_015_PMGD5_SLM en 202407010000:
# Datos para MALLOCO_012_PMGD5_PNF en 202405010000:
# Datos para MALLOCO_012_PMGD5_PNF en 202406010000:
# Datos para MALLOCO_012_PMGD5_PNF en 202407010000:
# Datos para CURICO_013_PMGD7_LCH en 202405010000:
# Datos para CURICO_013_PMGD7_LCH en 202406010000:
# Datos para CURICO_013_PMGD7_LCH en 202407010000:

# %%
data_by_measure_point.keys()
# Out:
# dict_keys(['URIBE_023_PMGD2_UAS', 'TAMANGO_066_B1_IUN', 'RENGO_015_PMGD5_SLM', 'MALLOCO_012_PMGD5_PNF', 'CURICO_013_PMGD7_LCH'])

# %%
data_by_measure_point['URIBE_023_PMGD2_UAS'].keys()
# Out:
# dict_keys(['202405010000', '202406010000', '202407010000'])

# %%
data_by_measure_point['URIBE_023_PMGD2_UAS']['202405010000']
# Out:
# [{'blog': None,
#   'coordinatorId': 'CE URIBE DE ANTOFAGASTA SOLAR',
#   'measurePointId': 'URIBE_023_PMGD2_UAS',
#   'period': 202405,
#   'subStation': 'URIBE',
#   'lastReadingDate': '2024-05-31T23:45:00.000+00:00',
#   'idSoc': None,
#   'measurer': [{'name': 'MR2007A08002_0100', 'principal': True}],
#   'channel': [{'channelId': 1,
#     'slug': 'kWhD',
#     'description': 'Retiro_Energia_Activa (kWhD)'},
#    {'channelId': 2,
#     'slug': 'kVarhD',
#     'description': 'Retiro_Energia_Reactiva (kVarhD)'},
#    {'channelId': 3,
#     'slug': 'kWhR',
#     'description': 'Inyección_Energia_Activa (kWhR)'},
#    {'channelId': 4,
#     'slug': 'kVarhR',
#     'description': 'Inyección_Energia_Reactiva (kVarhR)'}],
#   'measurement': [{'id': 17331235565,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T00:00:00.000+00:00',
#     'utcRange': '2024-05-01T04:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5866443,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7525806,
#     'channel5': 13476.6328125,
#     'channel6': 23121.0898438,
#     'channel7': 13454.7636719,
#     'channel8': 1.3771753,
#     'channel9': 1.3179772,
#     'channel10': 1.3209969,
#     'channel11': 16684.1621094,
#     'channel12': 1.3387165},
#    {'id': 17331235566,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T00:15:00.000+00:00',
#     'utcRange': '2024-05-01T04:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5952181,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.789999,
#     'channel5': 13508.1865234,
#     'channel6': 23175.2773438,
#     'channel7': 13485.2324219,
#     'channel8': 1.3814065,
#     'channel9': 1.321401,
#     'channel10': 1.3247216,
#     'channel11': 16722.8984375,
#     'channel12': 1.3425097},
#    {'id': 17331235567,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T00:30:00.000+00:00',
#     'utcRange': '2024-05-01T04:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6080489,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8048325,
#     'channel5': 13544.4492188,
#     'channel6': 23236.1972656,
#     'channel7': 13519.0283203,
#     'channel8': 1.3788868,
#     'channel9': 1.3202305,
#     'channel10': 1.32047,
#     'channel11': 16766.5585938,
#     'channel12': 1.3398625},
#    {'id': 17331235568,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T00:45:00.000+00:00',
#     'utcRange': '2024-05-01T04:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.620417,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7785492,
#     'channel5': 13570.078125,
#     'channel6': 23280.140625,
#     'channel7': 13542.7226563,
#     'channel8': 1.3768313,
#     'channel9': 1.3183309,
#     'channel10': 1.3190719,
#     'channel11': 16797.6464844,
#     'channel12': 1.338078},
#    {'id': 17331235569,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T01:00:00.000+00:00',
#     'utcRange': '2024-05-01T05:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6378728,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8291597,
#     'channel5': 13607.8964844,
#     'channel6': 23343.7890625,
#     'channel7': 13579.9423828,
#     'channel8': 1.3812013,
#     'channel9': 1.3251262,
#     'channel10': 1.3245417,
#     'channel11': 16843.8769531,
#     'channel12': 1.343623},
#    {'id': 17331235570,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T01:15:00.000+00:00',
#     'utcRange': '2024-05-01T05:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6410093,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8512249,
#     'channel5': 13615.3818359,
#     'channel6': 23356.5859375,
#     'channel7': 13587.75,
#     'channel8': 1.3822343,
#     'channel9': 1.32605,
#     'channel10': 1.3259209,
#     'channel11': 16853.2382813,
#     'channel12': 1.344735},
#    {'id': 17331235571,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T01:30:00.000+00:00',
#     'utcRange': '2024-05-01T05:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6365041,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8440771,
#     'channel5': 13606.0546875,
#     'channel6': 23341.2480469,
#     'channel7': 13578.0693359,
#     'channel8': 1.3830205,
#     'channel9': 1.3263519,
#     'channel10': 1.3261613,
#     'channel11': 16841.7910156,
#     'channel12': 1.3451779},
#    {'id': 17331235572,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T01:45:00.000+00:00',
#     'utcRange': '2024-05-01T05:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6364561,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8580074,
#     'channel5': 13608.8613281,
#     'channel6': 23347.8945313,
#     'channel7': 13583.1953125,
#     'channel8': 1.3843473,
#     'channel9': 1.3276052,
#     'channel10': 1.3276807,
#     'channel11': 16846.6503906,
#     'channel12': 1.3465444},
#    {'id': 17331235573,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T02:00:00.000+00:00',
#     'utcRange': '2024-05-01T06:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6070005,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7819757,
#     'channel5': 13512.2246094,
#     'channel6': 23181.8554688,
#     'channel7': 13486.9755859,
#     'channel8': 1.3819258,
#     'channel9': 1.3241564,
#     'channel10': 1.3260885,
#     'channel11': 16727.0175781,
#     'channel12': 1.344057},
#    {'id': 17331235574,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T02:15:00.000+00:00',
#     'utcRange': '2024-05-01T06:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6111895,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8018894,
#     'channel5': 13529.5117188,
#     'channel6': 23211.3984375,
#     'channel7': 13502.2519531,
#     'channel8': 1.3840282,
#     'channel9': 1.3264613,
#     'channel10': 1.3282611,
#     'channel11': 16747.7207031,
#     'channel12': 1.3462502},
#    {'id': 17331235575,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T02:30:00.000+00:00',
#     'utcRange': '2024-05-01T06:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6120306,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8079472,
#     'channel5': 13532.3320313,
#     'channel6': 23218.03125,
#     'channel7': 13507.3583984,
#     'channel8': 1.3847338,
#     'channel9': 1.3268381,
#     'channel10': 1.3291427,
#     'channel11': 16752.5742188,
#     'channel12': 1.3469049},
#    {'id': 17331235576,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T02:45:00.000+00:00',
#     'utcRange': '2024-05-01T06:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6127535,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7737894,
#     'channel5': 13528.6191406,
#     'channel6': 23210.8691406,
#     'channel7': 13503.0351563,
#     'channel8': 1.3819728,
#     'channel9': 1.3233378,
#     'channel10': 1.3266811,
#     'channel11': 16747.5078125,
#     'channel12': 1.3439972},
#    {'id': 17331235577,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T03:00:00.000+00:00',
#     'utcRange': '2024-05-01T07:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6086971,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7390089,
#     'channel5': 13506.7304688,
#     'channel6': 23174.2519531,
#     'channel7': 13483.0683594,
#     'channel8': 1.379898,
#     'channel9': 1.320027,
#     'channel10': 1.323954,
#     'channel11': 16721.3496094,
#     'channel12': 1.341293},
#    {'id': 17331235578,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T03:15:00.000+00:00',
#     'utcRange': '2024-05-01T07:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.611905,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7370052,
#     'channel5': 13513.2626953,
#     'channel6': 23188.1503906,
#     'channel7': 13491.5556641,
#     'channel8': 1.3806607,
#     'channel9': 1.3202533,
#     'channel10': 1.3236796,
#     'channel11': 16730.9902344,
#     'channel12': 1.3415312},
#    {'id': 17331235579,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T03:30:00.000+00:00',
#     'utcRange': '2024-05-01T07:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6115428,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7433739,
#     'channel5': 13515.6474609,
#     'channel6': 23191.5039063,
#     'channel7': 13493.2509766,
#     'channel8': 1.3797337,
#     'channel9': 1.3195921,
#     'channel10': 1.3226973,
#     'channel11': 16733.4667969,
#     'channel12': 1.3406743},
#    {'id': 17331235580,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T03:45:00.000+00:00',
#     'utcRange': '2024-05-01T07:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6165888,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7493486,
#     'channel5': 13523.9765625,
#     'channel6': 23204.5214844,
#     'channel7': 13500.6044922,
#     'channel8': 1.3792195,
#     'channel9': 1.3189692,
#     'channel10': 1.3220804,
#     'channel11': 16743.0351563,
#     'channel12': 1.3400898},
#    {'id': 17331235581,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T04:00:00.000+00:00',
#     'utcRange': '2024-05-01T08:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6173689,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.6851702,
#     'channel5': 13493.0146484,
#     'channel6': 23153.1425781,
#     'channel7': 13470.1572266,
#     'channel8': 1.3726985,
#     'channel9': 1.3145394,
#     'channel10': 1.3159746,
#     'channel11': 16705.4375,
#     'channel12': 1.3344042},
#    {'id': 17331235582,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T04:15:00.000+00:00',
#     'utcRange': '2024-05-01T08:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6132091,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7452564,
#     'channel5': 13494.0097656,
#     'channel6': 23153.5917969,
#     'channel7': 13469.4990234,
#     'channel8': 1.3789582,
#     'channel9': 1.3218997,
#     'channel10': 1.3234525,
#     'channel11': 16705.7011719,
#     'channel12': 1.3414367},
#    {'id': 17331235583,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T04:30:00.000+00:00',
#     'utcRange': '2024-05-01T08:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6068836,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7184839,
#     'channel5': 13473.2402344,
#     'channel6': 23119.3085938,
#     'channel7': 13451.0800781,
#     'channel8': 1.3761986,
#     'channel9': 1.3189257,
#     'channel10': 1.3202674,
#     'channel11': 16681.2089844,
#     'channel12': 1.338464},
#    {'id': 17331235584,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T04:45:00.000+00:00',
#     'utcRange': '2024-05-01T08:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6424906,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7524939,
#     'channel5': 13482.0117188,
#     'channel6': 23130.6171875,
#     'channel7': 13457.1376953,
#     'channel8': 1.3828614,
#     'channel9': 1.3275044,
#     'channel10': 1.3223685,
#     'channel11': 16689.921875,
#     'channel12': 1.3442447},
#    {'id': 17331235585,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T05:00:00.000+00:00',
#     'utcRange': '2024-05-01T09:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6116087,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7936363,
#     'channel5': 13495.7451172,
#     'channel6': 23153.2285156,
#     'channel7': 13469.0966797,
#     'channel8': 1.3844339,
#     'channel9': 1.3271567,
#     'channel10': 1.3284608,
#     'channel11': 16706.0234375,
#     'channel12': 1.3466837},
#    {'id': 17331235586,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T05:15:00.000+00:00',
#     'utcRange': '2024-05-01T09:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6050156,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8038263,
#     'channel5': 13502.515625,
#     'channel6': 23163.9492188,
#     'channel7': 13474.0830078,
#     'channel8': 1.3864255,
#     'channel9': 1.3287961,
#     'channel10': 1.3310651,
#     'channel11': 16713.515625,
#     'channel12': 1.3487623},
#    {'id': 17331235587,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T05:30:00.000+00:00',
#     'utcRange': '2024-05-01T09:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6046212,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8012533,
#     'channel5': 13500.9824219,
#     'channel6': 23161.0976563,
#     'channel7': 13472.5800781,
#     'channel8': 1.3869016,
#     'channel9': 1.3281168,
#     'channel10': 1.3314559,
#     'channel11': 16711.5527344,
#     'channel12': 1.3488247},
#    {'id': 17331235588,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T05:45:00.000+00:00',
#     'utcRange': '2024-05-01T09:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6013676,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.791544,
#     'channel5': 13491.3447266,
#     'channel6': 23144.1152344,
#     'channel7': 13462.9794922,
#     'channel8': 1.3874758,
#     'channel9': 1.3278779,
#     'channel10': 1.3312211,
#     'channel11': 16699.4804688,
#     'channel12': 1.3488582},
#    {'id': 17331235589,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T06:00:00.000+00:00',
#     'utcRange': '2024-05-01T10:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5990618,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7631941,
#     'channel5': 13477.4306641,
#     'channel6': 23119.9824219,
#     'channel7': 13449.6210938,
#     'channel8': 1.3855947,
#     'channel9': 1.3251745,
#     'channel10': 1.3284003,
#     'channel11': 16682.3457031,
#     'channel12': 1.3463899},
#    {'id': 17331235590,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T06:15:00.000+00:00',
#     'utcRange': '2024-05-01T10:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5981238,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7076845,
#     'channel5': 13456.5556641,
#     'channel6': 23084.3691406,
#     'channel7': 13427.8408203,
#     'channel8': 1.378543,
#     'channel9': 1.3180161,
#     'channel10': 1.3216921,
#     'channel11': 16656.2539063,
#     'channel12': 1.3394171},
#    {'id': 17331235591,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T06:30:00.000+00:00',
#     'utcRange': '2024-05-01T10:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5823371,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.710494,
#     'channel5': 13457.1298828,
#     'channel6': 23087.3710938,
#     'channel7': 13428.2636719,
#     'channel8': 1.3769188,
#     'channel9': 1.3173653,
#     'channel10': 1.3203963,
#     'channel11': 16657.5878906,
#     'channel12': 1.3382268},
#    {'id': 17331235592,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T06:45:00.000+00:00',
#     'utcRange': '2024-05-01T10:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5089083,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.6722622,
#     'channel5': 13444.7089844,
#     'channel6': 23065.1035156,
#     'channel7': 13414.2392578,
#     'channel8': 1.3701438,
#     'channel9': 1.3129153,
#     'channel10': 1.3117267,
#     'channel11': 16641.3496094,
#     'channel12': 1.3315953},
#    {'id': 17331235593,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T07:00:00.000+00:00',
#     'utcRange': '2024-05-01T11:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.4071256,
#     'channel2': 0.0,
#     'channel3': 0.1067821,
#     'channel4': 8.8405752,
#     'channel5': 13493.7470703,
#     'channel6': 23146.4414063,
#     'channel7': 13458.4091797,
#     'channel8': 1.4329035,
#     'channel9': 1.3824166,
#     'channel10': 1.372393,
#     'channel11': 16699.53125,
#     'channel12': 1.3959044},
#    {'id': 17331235594,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T07:15:00.000+00:00',
#     'utcRange': '2024-05-01T11:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.0,
#     'channel3': 11.8072262,
#     'channel4': 8.603178,
#     'channel5': 13561.2509766,
#     'channel6': 23262.234375,
#     'channel7': 13525.375,
#     'channel8': 3.0221186,
#     'channel9': 2.9968469,
#     'channel10': 2.8066432,
#     'channel11': 16782.953125,
#     'channel12': 2.9418695},
#    {'id': 17331235595,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T07:30:00.000+00:00',
#     'utcRange': '2024-05-01T11:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.0,
#     'channel3': 39.8274803,
#     'channel4': 8.4226074,
#     'channel5': 13562.0507813,
#     'channel6': 23267.5429688,
#     'channel7': 13528.2978516,
#     'channel8': 6.4793696,
#     'channel9': 6.4282856,
#     'channel10': 6.2493281,
#     'channel11': 16785.9628906,
#     'channel12': 6.3856611},
#    {'id': 17331235596,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T07:45:00.000+00:00',
#     'utcRange': '2024-05-01T11:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.0,
#     'channel3': 66.4992905,
#     'channel4': 8.3021841,
#     'channel5': 13483.8378906,
#     'channel6': 23131.75,
#     'channel7': 13447.1630859,
#     'channel8': 10.2625675,
#     'channel9': 10.1995668,
#     'channel10': 10.0311928,
#     'channel11': 16687.5839844,
#     'channel12': 10.1644421},
#    {'id': 17331235597,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T08:00:00.000+00:00',
#     'utcRange': '2024-05-01T12:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.0,
#     'channel3': 156.8002472,
#     'channel4': 7.0943346,
#     'channel5': 13397.8388672,
#     'channel6': 22981.9980469,
#     'channel7': 13358.9677734,
#     'channel8': 23.7033291,
#     'channel9': 23.6310863,
#     'channel10': 23.4737148,
#     'channel11': 16579.6015625,
#     'channel12': 23.6027107},
#    {'id': 17331235598,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T08:15:00.000+00:00',
#     'utcRange': '2024-05-01T12:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.1188908,
#     'channel3': 300.4741821,
#     'channel4': 3.8915169,
#     'channel5': 13463.4335938,
#     'channel6': 23091.0703125,
#     'channel7': 13418.5625,
#     'channel8': 44.9061775,
#     'channel9': 44.8025894,
#     'channel10': 44.6804276,
#     'channel11': 16657.6875,
#     'channel12': 44.7963982},
#    {'id': 17331235599,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T08:30:00.000+00:00',
#     'utcRange': '2024-05-01T12:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 17.0663261,
#     'channel3': 779.9362793,
#     'channel4': 0.0187161,
#     'channel5': 13585.0126953,
#     'channel6': 23294.2519531,
#     'channel7': 13528.6054688,
#     'channel8': 115.2197723,
#     'channel9': 115.0655365,
#     'channel10': 115.051445,
#     'channel11': 16802.6230469,
#     'channel12': 115.1122513},
#    {'id': 17331235600,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T08:45:00.000+00:00',
#     'utcRange': '2024-05-01T12:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 29.3641434,
#     'channel3': 974.9647827,
#     'channel4': 0.0,
#     'channel5': 13428.0595703,
#     'channel6': 23024.6308594,
#     'channel7': 13374.5585938,
#     'channel8': 145.7419281,
#     'channel9': 145.5884857,
#     'channel10': 145.6074524,
#     'channel11': 16609.0839844,
#     'channel12': 145.6459503},
#    {'id': 17331235601,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T09:00:00.000+00:00',
#     'utcRange': '2024-05-01T13:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 28.8079376,
#     'channel3': 968.5228882,
#     'channel4': 0.0049335,
#     'channel5': 13515.5986328,
#     'channel6': 23174.9960938,
#     'channel7': 13458.8837891,
#     'channel8': 143.8549194,
#     'channel9': 143.7147369,
#     'channel10': 143.7181702,
#     'channel11': 16716.4921875,
#     'channel12': 143.7626038},
#    {'id': 17331235602,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T09:15:00.000+00:00',
#     'utcRange': '2024-05-01T13:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 32.9970093,
#     'channel3': 1025.8503418,
#     'channel4': 0.0,
#     'channel5': 13531.6767578,
#     'channel6': 23199.2597656,
#     'channel7': 13471.2578125,
#     'channel8': 152.2149506,
#     'channel9': 152.0626831,
#     'channel10': 152.07341,
#     'channel11': 16734.0644531,
#     'channel12': 152.1170044},
#    {'id': 17331235603,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T09:30:00.000+00:00',
#     'utcRange': '2024-05-01T13:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 33.9845924,
#     'channel3': 1038.010498,
#     'channel4': 0.0,
#     'channel5': 13539.4257813,
#     'channel6': 23210.125,
#     'channel7': 13473.4287109,
#     'channel8': 153.9594879,
#     'channel9': 153.814743,
#     'channel10': 153.8188934,
#     'channel11': 16740.9941406,
#     'channel12': 153.8643799},
#    {'id': 17331235604,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T09:45:00.000+00:00',
#     'utcRange': '2024-05-01T13:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 34.5510712,
#     'channel3': 1046.2515869,
#     'channel4': 0.0,
#     'channel5': 13536.7880859,
#     'channel6': 23203.7617188,
#     'channel7': 13470.2041016,
#     'channel8': 155.2208405,
#     'channel9': 155.0720367,
#     'channel10': 155.0718079,
#     'channel11': 16736.9179688,
#     'channel12': 155.1215668},
#    {'id': 17331235605,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T10:00:00.000+00:00',
#     'utcRange': '2024-05-01T14:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 35.1917419,
#     'channel3': 1050.5238037,
#     'channel4': 0.0,
#     'channel5': 13536.5195313,
#     'channel6': 23201.5722656,
#     'channel7': 13469.0839844,
#     'channel8': 155.8533783,
#     'channel9': 155.71521,
#     'channel10': 155.7196503,
#     'channel11': 16735.7246094,
#     'channel12': 155.7627411},
#    {'id': 17331235606,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T10:15:00.000+00:00',
#     'utcRange': '2024-05-01T14:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 35.7847633,
#     'channel3': 1055.5568848,
#     'channel4': 0.0,
#     'channel5': 13517.2871094,
#     'channel6': 23169.5605469,
#     'channel7': 13452.4394531,
#     'channel8': 156.7992096,
#     'channel9': 156.667099,
#     'channel10': 156.6828766,
#     'channel11': 16713.0957031,
#     'channel12': 156.7164001},
#    {'id': 17331235607,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T10:30:00.000+00:00',
#     'utcRange': '2024-05-01T14:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 37.7113647,
#     'channel3': 1074.9112549,
#     'channel4': 0.0,
#     'channel5': 13480.0371094,
#     'channel6': 23106.28125,
#     'channel7': 13415.796875,
#     'channel8': 160.1419983,
#     'channel9': 159.984375,
#     'channel10': 159.9945374,
#     'channel11': 16667.3710938,
#     'channel12': 160.0403137},
#    {'id': 17331235608,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T10:45:00.000+00:00',
#     'utcRange': '2024-05-01T14:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 38.4919014,
#     'channel3': 1079.0130615,
#     'channel4': 0.0,
#     'channel5': 13442.0693359,
#     'channel6': 23040.0175781,
#     'channel7': 13375.1914063,
#     'channel8': 161.2362823,
#     'channel9': 161.0583038,
#     'channel10': 161.0906067,
#     'channel11': 16619.09375,
#     'channel12': 161.1284027},
#    {'id': 17331235609,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T11:00:00.000+00:00',
#     'utcRange': '2024-05-01T15:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 38.1050377,
#     'channel3': 1079.1029053,
#     'channel4': 0.0,
#     'channel5': 13437.5791016,
#     'channel6': 23034.8964844,
#     'channel7': 13373.4980469,
#     'channel8': 161.2852783,
#     'channel9': 161.1055756,
#     'channel10': 161.1414032,
#     'channel11': 16615.3242188,
#     'channel12': 161.1774139},
#    {'id': 17331235610,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T11:15:00.000+00:00',
#     'utcRange': '2024-05-01T15:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 38.2236938,
#     'channel3': 1078.6459961,
#     'channel4': 0.0,
#     'channel5': 13432.7890625,
#     'channel6': 23027.3105469,
#     'channel7': 13367.9345703,
#     'channel8': 161.288147,
#     'channel9': 161.1085205,
#     'channel10': 161.1274872,
#     'channel11': 16609.3457031,
#     'channel12': 161.1747131},
#    {'id': 17331235611,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T11:30:00.000+00:00',
#     'utcRange': '2024-05-01T15:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 38.358448,
#     'channel3': 1078.1256104,
#     'channel4': 0.0,
#     'channel5': 13437.9082031,
#     'channel6': 23032.4355469,
#     'channel7': 13369.2177734,
#     'channel8': 161.1665192,
#     'channel9': 160.9974518,
#     'channel10': 161.0030975,
#     'channel11': 16613.1875,
#     'channel12': 161.0556946},
#    {'id': 17331235612,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T11:45:00.000+00:00',
#     'utcRange': '2024-05-01T15:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 38.777935,
#     'channel3': 1079.4606934,
#     'channel4': 0.0,
#     'channel5': 13435.7958984,
#     'channel6': 23029.1738281,
#     'channel7': 13368.9775391,
#     'channel8': 161.3674774,
#     'channel9': 161.2120819,
#     'channel10': 161.2245483,
#     'channel11': 16611.3164063,
#     'channel12': 161.2680359},
#    {'id': 17331235613,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T12:00:00.000+00:00',
#     'utcRange': '2024-05-01T16:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 38.423317,
#     'channel3': 1080.7929688,
#     'channel4': 0.0,
#     'channel5': 13426.0410156,
#     'channel6': 23011.421875,
#     'channel7': 13357.1396484,
#     'channel8': 161.6916809,
#     'channel9': 161.5397797,
#     'channel10': 161.5414581,
#     'channel11': 16598.2011719,
#     'channel12': 161.5909729},
#    {'id': 17331235614,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T12:15:00.000+00:00',
#     'utcRange': '2024-05-01T16:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 38.6284256,
#     'channel3': 1080.7990723,
#     'channel4': 0.0,
#     'channel5': 13401.2451172,
#     'channel6': 22974.7089844,
#     'channel7': 13337.8330078,
#     'channel8': 161.9653473,
#     'channel9': 161.8060455,
#     'channel10': 161.8173828,
#     'channel11': 16571.2617188,
#     'channel12': 161.8629303},
#    {'id': 17331235615,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T12:30:00.000+00:00',
#     'utcRange': '2024-05-01T16:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 39.2746239,
#     'channel3': 1081.022583,
#     'channel4': 0.0,
#     'channel5': 13368.6835938,
#     'channel6': 22917.6953125,
#     'channel7': 13303.9648438,
#     'channel8': 162.3970184,
#     'channel9': 162.2524109,
#     'channel10': 162.2451782,
#     'channel11': 16530.1152344,
#     'channel12': 162.2982025},
#    {'id': 17331235616,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T12:45:00.000+00:00',
#     'utcRange': '2024-05-01T16:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 31.7391167,
#     'channel3': 993.9266357,
#     'channel4': 0.0,
#     'channel5': 13365.3203125,
#     'channel6': 22913.4082031,
#     'channel7': 13302.2392578,
#     'channel8': 149.3141479,
#     'channel9': 149.1850281,
#     'channel10': 149.1858978,
#     'channel11': 16526.9882813,
#     'channel12': 149.2283478},
#    {'id': 17331235617,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T13:00:00.000+00:00',
#     'utcRange': '2024-05-01T17:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 23.829174,
#     'channel3': 891.4003906,
#     'channel4': 0.0,
#     'channel5': 13332.3115234,
#     'channel6': 22861.1796875,
#     'channel7': 13276.2353516,
#     'channel8': 134.176239,
#     'channel9': 134.0824738,
#     'channel10': 134.0527191,
#     'channel11': 16489.9082031,
#     'channel12': 134.1038055},
#    {'id': 17331235618,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T13:15:00.000+00:00',
#     'utcRange': '2024-05-01T17:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 21.9466171,
#     'channel3': 858.9590454,
#     'channel4': 0.0,
#     'channel5': 13287.3857422,
#     'channel6': 22786.2402344,
#     'channel7': 13234.5126953,
#     'channel8': 129.7184143,
#     'channel9': 129.6321106,
#     'channel10': 129.5878296,
#     'channel11': 16436.046875,
#     'channel12': 129.6461182},
#    {'id': 17331235619,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T13:30:00.000+00:00',
#     'utcRange': '2024-05-01T17:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 17.8546658,
#     'channel3': 796.0543213,
#     'channel4': 0.0,
#     'channel5': 13318.3134766,
#     'channel6': 22841.4707031,
#     'channel7': 13266.9609375,
#     'channel8': 119.9502563,
#     'channel9': 119.8511963,
#     'channel10': 119.8216705,
#     'channel11': 16475.5820313,
#     'channel12': 119.8743744},
#    {'id': 17331235620,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T13:45:00.000+00:00',
#     'utcRange': '2024-05-01T17:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 16.5726223,
#     'channel3': 785.4534302,
#     'channel4': 0.0,
#     'channel5': 13425.6630859,
#     'channel6': 23023.1074219,
#     'channel7': 13372.3828125,
#     'channel8': 117.4089813,
#     'channel9': 117.3011322,
#     'channel10': 117.2679901,
#     'channel11': 16607.0507813,
#     'channel12': 117.3260345},
#    {'id': 17331235621,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T14:00:00.000+00:00',
#     'utcRange': '2024-05-01T18:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 38.0655708,
#     'channel3': 1076.8792725,
#     'channel4': 0.0,
#     'channel5': 13425.0986328,
#     'channel6': 23017.3847656,
#     'channel7': 13368.1171875,
#     'channel8': 161.0600128,
#     'channel9': 160.8852692,
#     'channel10': 160.9088135,
#     'channel11': 16603.5332031,
#     'channel12': 160.9513702},
#    {'id': 17331235622,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T14:15:00.000+00:00',
#     'utcRange': '2024-05-01T18:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 40.613533,
#     'channel3': 1107.12854,
#     'channel4': 0.0,
#     'channel5': 13426.1386719,
#     'channel6': 23022.0957031,
#     'channel7': 13370.5107422,
#     'channel8': 165.5758972,
#     'channel9': 165.3885651,
#     'channel10': 165.4091949,
#     'channel11': 16606.2480469,
#     'channel12': 165.4578857},
#    {'id': 17331235623,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T14:30:00.000+00:00',
#     'utcRange': '2024-05-01T18:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 40.8372383,
#     'channel3': 1104.5994873,
#     'channel4': 0.0,
#     'channel5': 13425.8183594,
#     'channel6': 23021.5761719,
#     'channel7': 13371.1923828,
#     'channel8': 165.1836395,
#     'channel9': 165.0188293,
#     'channel10': 165.0305023,
#     'channel11': 16606.1953125,
#     'channel12': 165.077652},
#    {'id': 17331235624,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T14:45:00.000+00:00',
#     'utcRange': '2024-05-01T18:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 41.215313,
#     'channel3': 1109.2855225,
#     'channel4': 0.0,
#     'channel5': 13423.0498047,
#     'channel6': 23019.9296875,
#     'channel7': 13371.96875,
#     'channel8': 165.8827362,
#     'channel9': 165.7243652,
#     'channel10': 165.7494507,
#     'channel11': 16604.9824219,
#     'channel12': 165.7855225},
#    {'id': 17331235625,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T15:00:00.000+00:00',
#     'utcRange': '2024-05-01T19:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 40.1323318,
#     'channel3': 1102.6934814,
#     'channel4': 0.0,
#     'channel5': 13446.2958984,
#     'channel6': 23058.3222656,
#     'channel7': 13394.3583984,
#     'channel8': 164.6111145,
#     'channel9': 164.458725,
#     'channel10': 164.4779663,
#     'channel11': 16632.9921875,
#     'channel12': 164.5159302},
#    {'id': 17331235626,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T15:15:00.000+00:00',
#     'utcRange': '2024-05-01T19:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 39.0751228,
#     'channel3': 1095.6870117,
#     'channel4': 0.0,
#     'channel5': 13460.296875,
#     'channel6': 23082.9550781,
#     'channel7': 13408.5869141,
#     'channel8': 163.3812103,
#     'channel9': 163.243927,
#     'channel10': 163.2520294,
#     'channel11': 16650.6132813,
#     'channel12': 163.2923889},
#    {'id': 17331235627,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T15:30:00.000+00:00',
#     'utcRange': '2024-05-01T19:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 38.7889671,
#     'channel3': 1090.7496338,
#     'channel4': 0.0,
#     'channel5': 13457.5234375,
#     'channel6': 23079.46875,
#     'channel7': 13407.4189453,
#     'channel8': 162.6789551,
#     'channel9': 162.5331726,
#     'channel10': 162.5338593,
#     'channel11': 16648.1367188,
#     'channel12': 162.5820007},
#    {'id': 17331235628,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T15:45:00.000+00:00',
#     'utcRange': '2024-05-01T19:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 37.708416,
#     'channel3': 1076.0141602,
#     'channel4': 0.0,
#     'channel5': 13468.9042969,
#     'channel6': 23096.5488281,
#     'channel7': 13416.6230469,
#     'channel8': 160.3657837,
#     'channel9': 160.2108154,
#     'channel10': 160.2159729,
#     'channel11': 16660.6914063,
#     'channel12': 160.2641907},
#    {'id': 17331235629,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T16:00:00.000+00:00',
#     'utcRange': '2024-05-01T20:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 35.6460648,
#     'channel3': 1055.2404785,
#     'channel4': 0.0,
#     'channel5': 13519.5039063,
#     'channel6': 23184.0683594,
#     'channel7': 13464.3173828,
#     'channel8': 156.6895294,
#     'channel9': 156.5468597,
#     'channel10': 156.5432129,
#     'channel11': 16722.6308594,
#     'channel12': 156.5932007},
#    {'id': 17331235630,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T16:15:00.000+00:00',
#     'utcRange': '2024-05-01T20:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 32.2798729,
#     'channel3': 1019.6954956,
#     'channel4': 0.0,
#     'channel5': 13539.4570313,
#     'channel6': 23220.1621094,
#     'channel7': 13485.9863281,
#     'channel8': 151.1642456,
#     'channel9': 151.020462,
#     'channel10': 151.0290375,
#     'channel11': 16748.5351563,
#     'channel12': 151.0712585},
#    {'id': 17331235631,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T16:30:00.000+00:00',
#     'utcRange': '2024-05-01T20:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 29.008028,
#     'channel3': 979.8370361,
#     'channel4': 0.0,
#     'channel5': 13544.2753906,
#     'channel6': 23229.0957031,
#     'channel7': 13491.9570313,
#     'channel8': 145.1834717,
#     'channel9': 145.0552979,
#     'channel10': 145.0496826,
#     'channel11': 16755.109375,
#     'channel12': 145.0961456},
#    {'id': 17331235632,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T16:45:00.000+00:00',
#     'utcRange': '2024-05-01T20:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 12.0783072,
#     'channel3': 663.6576538,
#     'channel4': 0.5214942,
#     'channel5': 13480.6113281,
#     'channel6': 23126.3730469,
#     'channel7': 13440.8291016,
#     'channel8': 98.7395248,
#     'channel9': 98.6448517,
#     'channel10': 98.591217,
#     'channel11': 16682.6035156,
#     'channel12': 98.6585312},
#    {'id': 17331235633,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T17:00:00.000+00:00',
#     'utcRange': '2024-05-01T21:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 9.0265055,
#     'channel3': 646.3513794,
#     'channel4': 0.002492,
#     'channel5': 13489.7138672,
#     'channel6': 23145.234375,
#     'channel7': 13453.1621094,
#     'channel8': 96.106842,
#     'channel9': 96.023407,
#     'channel10': 95.97332,
#     'channel11': 16696.0371094,
#     'channel12': 96.034523},
#    {'id': 17331235634,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T17:15:00.000+00:00',
#     'utcRange': '2024-05-01T21:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.7733574,
#     'channel3': 416.1624146,
#     'channel4': 1.5607146,
#     'channel5': 13437.5986328,
#     'channel6': 23057.8925781,
#     'channel7': 13405.4208984,
#     'channel8': 62.1354523,
#     'channel9': 62.0550957,
#     'channel10': 61.9801712,
#     'channel11': 16633.6367188,
#     'channel12': 62.0569077},
#    {'id': 17331235635,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T17:30:00.000+00:00',
#     'utcRange': '2024-05-01T21:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.0,
#     'channel3': 127.4657211,
#     'channel4': 7.1748214,
#     'channel5': 13385.453125,
#     'channel6': 22972.6503906,
#     'channel7': 13360.8925781,
#     'channel8': 19.4151821,
#     'channel9': 19.3786469,
#     'channel10': 19.2364902,
#     'channel11': 16572.9980469,
#     'channel12': 19.3434391},
#    {'id': 17331235636,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T17:45:00.000+00:00',
#     'utcRange': '2024-05-01T21:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.0,
#     'channel3': 28.1194649,
#     'channel4': 8.3074961,
#     'channel5': 13415.6943359,
#     'channel6': 23018.5839844,
#     'channel7': 13392.1337891,
#     'channel8': 4.8574963,
#     'channel9': 4.82093,
#     'channel10': 4.6638923,
#     'channel11': 16608.8046875,
#     'channel12': 4.7807732},
#    {'id': 17331235637,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T18:00:00.000+00:00',
#     'utcRange': '2024-05-01T22:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.4079136,
#     'channel2': 0.0,
#     'channel3': 7.1121941,
#     'channel4': 8.3973055,
#     'channel5': 13390.7275391,
#     'channel6': 22978.734375,
#     'channel7': 13371.2480469,
#     'channel8': 2.4306977,
#     'channel9': 2.4007258,
#     'channel10': 2.300251,
#     'channel11': 16580.2363281,
#     'channel12': 2.3772249},
#    {'id': 17331235638,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T18:15:00.000+00:00',
#     'utcRange': '2024-05-01T22:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.8375458,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7462168,
#     'channel5': 13338.2714844,
#     'channel6': 22899.3300781,
#     'channel7': 13330.28125,
#     'channel8': 1.3964185,
#     'channel9': 1.3388836,
#     'channel10': 1.3429165,
#     'channel11': 16522.6269531,
#     'channel12': 1.3594062},
#    {'id': 17331235639,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T18:30:00.000+00:00',
#     'utcRange': '2024-05-01T22:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5150787,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.74226,
#     'channel5': 13296.734375,
#     'channel6': 22830.8007813,
#     'channel7': 13293.9775391,
#     'channel8': 1.3892169,
#     'channel9': 1.3299547,
#     'channel10': 1.3297735,
#     'channel11': 16473.8378906,
#     'channel12': 1.3496485},
#    {'id': 17331235640,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T18:45:00.000+00:00',
#     'utcRange': '2024-05-01T22:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5427978,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.6875048,
#     'channel5': 13298.4677734,
#     'channel6': 22833.7460938,
#     'channel7': 13298.7597656,
#     'channel8': 1.3827714,
#     'channel9': 1.3222278,
#     'channel10': 1.3228072,
#     'channel11': 16476.9902344,
#     'channel12': 1.3426021},
#    {'id': 17331235641,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T19:00:00.000+00:00',
#     'utcRange': '2024-05-01T23:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5381638,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.5817509,
#     'channel5': 13290.3164063,
#     'channel6': 22820.9433594,
#     'channel7': 13293.9628906,
#     'channel8': 1.3673038,
#     'channel9': 1.3051329,
#     'channel10': 1.3081999,
#     'channel11': 16468.4082031,
#     'channel12': 1.3268789},
#    {'id': 17331235642,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T19:15:00.000+00:00',
#     'utcRange': '2024-05-01T23:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5700095,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.5593748,
#     'channel5': 13289.2431641,
#     'channel6': 22821.6542969,
#     'channel7': 13293.7714844,
#     'channel8': 1.3661705,
#     'channel9': 1.3061092,
#     'channel10': 1.3042541,
#     'channel11': 16468.2226563,
#     'channel12': 1.3255112},
#    {'id': 17331235643,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T19:30:00.000+00:00',
#     'utcRange': '2024-05-01T23:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5570878,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.5561619,
#     'channel5': 13301.5517578,
#     'channel6': 22843.1855469,
#     'channel7': 13305.9697266,
#     'channel8': 1.3628957,
#     'channel9': 1.3031126,
#     'channel10': 1.3026333,
#     'channel11': 16483.5683594,
#     'channel12': 1.3228805},
#    {'id': 17331235644,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T19:45:00.000+00:00',
#     'utcRange': '2024-05-01T23:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5537887,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.5752048,
#     'channel5': 13315.7050781,
#     'channel6': 22868.0957031,
#     'channel7': 13320.8076172,
#     'channel8': 1.3652688,
#     'channel9': 1.304515,
#     'channel10': 1.305421,
#     'channel11': 16501.5351563,
#     'channel12': 1.3250684},
#    {'id': 17331235645,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T20:00:00.000+00:00',
#     'utcRange': '2024-05-02T00:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.547763,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.5591469,
#     'channel5': 13306.1669922,
#     'channel6': 22849.0957031,
#     'channel7': 13310.0136719,
#     'channel8': 1.3644609,
#     'channel9': 1.3033473,
#     'channel10': 1.305655,
#     'channel11': 16488.4257813,
#     'channel12': 1.3244878},
#    {'id': 17331235646,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T20:15:00.000+00:00',
#     'utcRange': '2024-05-02T00:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5433401,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.5262899,
#     'channel5': 13284.7285156,
#     'channel6': 22813.3886719,
#     'channel7': 13289.5146484,
#     'channel8': 1.3597004,
#     'channel9': 1.2996451,
#     'channel10': 1.3018067,
#     'channel11': 16462.5449219,
#     'channel12': 1.320384},
#    {'id': 17331235647,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T20:30:00.000+00:00',
#     'utcRange': '2024-05-02T00:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5444447,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.5581703,
#     'channel5': 13292.5761719,
#     'channel6': 22827.1113281,
#     'channel7': 13295.9267578,
#     'channel8': 1.3639237,
#     'channel9': 1.3039223,
#     'channel10': 1.3064221,
#     'channel11': 16471.8710938,
#     'channel12': 1.324756},
#    {'id': 17331235648,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T20:45:00.000+00:00',
#     'utcRange': '2024-05-02T00:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5473899,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.5791388,
#     'channel5': 13297.2783203,
#     'channel6': 22832.703125,
#     'channel7': 13298.6044922,
#     'channel8': 1.3670695,
#     'channel9': 1.3064293,
#     'channel10': 1.310514,
#     'channel11': 16476.1953125,
#     'channel12': 1.3280042},
#    {'id': 17331235649,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T21:00:00.000+00:00',
#     'utcRange': '2024-05-02T01:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5487993,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.5857363,
#     'channel5': 13298.0566406,
#     'channel6': 22833.3125,
#     'channel7': 13297.8496094,
#     'channel8': 1.3678497,
#     'channel9': 1.3074664,
#     'channel10': 1.3108829,
#     'channel11': 16476.40625,
#     'channel12': 1.328733},
#    {'id': 17331235650,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T21:15:00.000+00:00',
#     'utcRange': '2024-05-02T01:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5493114,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.5883942,
#     'channel5': 13304.1865234,
#     'channel6': 22842.7324219,
#     'channel7': 13302.4121094,
#     'channel8': 1.3668593,
#     'channel9': 1.3059968,
#     'channel10': 1.3094535,
#     'channel11': 16483.1113281,
#     'channel12': 1.3274364},
#    {'id': 17331235651,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T21:30:00.000+00:00',
#     'utcRange': '2024-05-02T01:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5526433,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.6236925,
#     'channel5': 13324.3945313,
#     'channel6': 22875.0703125,
#     'channel7': 13322.1357422,
#     'channel8': 1.3689346,
#     'channel9': 1.3085628,
#     'channel10': 1.3103818,
#     'channel11': 16507.2011719,
#     'channel12': 1.329293},
#    {'id': 17331235652,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-01T21:45:00.000+00:00',
#     'utcRange': '2024-05-02T01:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5591937,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.6595812,
#     'channel5': 13352.6894531,
#     'channel6': 22923.4394531,
#     'channel7': 13350.4970703,
#     'channel8': 1.3713975,
#     'channel9': 1.3112525,
#     'channel10': 1.3123199,
#     'channel11': 16542.2089844,
#     'channel12': 1.3316566},
#    {'id': 17331235653,
#     'yearx': 2024,
# ...
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T02:30:00.000+00:00',
#     'utcRange': '2024-05-11T06:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.611315,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7795763,
#     'channel5': 13520.0703125,
#     'channel6': 23202.7988281,
#     'channel7': 13505.4130859,
#     'channel8': 1.3852546,
#     'channel9': 1.3129849,
#     'channel10': 1.3206559,
#     'channel11': 16742.7597656,
#     'channel12': 1.3396318},
#    {'id': 17385270204,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T02:45:00.000+00:00',
#     'utcRange': '2024-05-11T06:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6110539,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7772598,
#     'channel5': 13516.25,
#     'channel6': 23197.4550781,
#     'channel7': 13501.2714844,
#     'channel8': 1.3854384,
#     'channel9': 1.313105,
#     'channel10': 1.3218763,
#     'channel11': 16738.3261719,
#     'channel12': 1.3401399},
#    {'id': 17385270205,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T03:00:00.000+00:00',
#     'utcRange': '2024-05-11T07:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6113709,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8020067,
#     'channel5': 13528.6318359,
#     'channel6': 23215.6542969,
#     'channel7': 13511.4560547,
#     'channel8': 1.3873816,
#     'channel9': 1.3144628,
#     'channel10': 1.3235183,
#     'channel11': 16751.9140625,
#     'channel12': 1.3417876},
#    {'id': 17385270206,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T03:15:00.000+00:00',
#     'utcRange': '2024-05-11T07:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6171815,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8101711,
#     'channel5': 13526.8623047,
#     'channel6': 23212.0175781,
#     'channel7': 13509.2421875,
#     'channel8': 1.3915224,
#     'channel9': 1.3153162,
#     'channel10': 1.3252316,
#     'channel11': 16749.375,
#     'channel12': 1.3440233},
#    {'id': 17385270207,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T03:30:00.000+00:00',
#     'utcRange': '2024-05-11T07:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6603968,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7723942,
#     'channel5': 13523.6748047,
#     'channel6': 23205.8125,
#     'channel7': 13505.7519531,
#     'channel8': 1.3991218,
#     'channel9': 1.3088477,
#     'channel10': 1.3241273,
#     'channel11': 16745.0800781,
#     'channel12': 1.3440323},
#    {'id': 17385270208,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T03:45:00.000+00:00',
#     'utcRange': '2024-05-11T07:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6185132,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7944727,
#     'channel5': 13520.2861328,
#     'channel6': 23200.4785156,
#     'channel7': 13503.0361328,
#     'channel8': 1.3895369,
#     'channel9': 1.3119383,
#     'channel10': 1.3231319,
#     'channel11': 16741.2675781,
#     'channel12': 1.3415357},
#    {'id': 17385270209,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T04:00:00.000+00:00',
#     'utcRange': '2024-05-11T08:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6051948,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8105917,
#     'channel5': 13521.4179688,
#     'channel6': 23201.2441406,
#     'channel7': 13503.765625,
#     'channel8': 1.3888481,
#     'channel9': 1.3147494,
#     'channel10': 1.3241751,
#     'channel11': 16742.1425781,
#     'channel12': 1.3425908},
#    {'id': 17385270210,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T04:15:00.000+00:00',
#     'utcRange': '2024-05-11T08:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6114247,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8431158,
#     'channel5': 13543.4667969,
#     'channel6': 23240.4414063,
#     'channel7': 13526.2880859,
#     'channel8': 1.3981947,
#     'channel9': 1.325561,
#     'channel10': 1.3336316,
#     'channel11': 16770.0644531,
#     'channel12': 1.3524624},
#    {'id': 17385270211,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T04:30:00.000+00:00',
#     'utcRange': '2024-05-11T08:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6127703,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8493013,
#     'channel5': 13550.8076172,
#     'channel6': 23252.3320313,
#     'channel7': 13532.7880859,
#     'channel8': 1.400565,
#     'channel9': 1.3275812,
#     'channel10': 1.3354465,
#     'channel11': 16778.6425781,
#     'channel12': 1.3545309},
#    {'id': 17385270212,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T04:45:00.000+00:00',
#     'utcRange': '2024-05-11T08:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.637771,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.8530464,
#     'channel5': 13558.9570313,
#     'channel6': 23267.9199219,
#     'channel7': 13541.8798828,
#     'channel8': 1.3994054,
#     'channel9': 1.3290824,
#     'channel10': 1.3337545,
#     'channel11': 16789.5859375,
#     'channel12': 1.3540808},
#    {'id': 17385270213,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T05:00:00.000+00:00',
#     'utcRange': '2024-05-11T09:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6785713,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7630825,
#     'channel5': 13520.3886719,
#     'channel6': 23203.2890625,
#     'channel7': 13501.2607422,
#     'channel8': 1.3949618,
#     'channel9': 1.3259757,
#     'channel10': 1.3277091,
#     'channel11': 16741.6464844,
#     'channel12': 1.3495488},
#    {'id': 17385270214,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T05:15:00.000+00:00',
#     'utcRange': '2024-05-11T09:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6119493,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7722559,
#     'channel5': 13522.4482422,
#     'channel6': 23208.0371094,
#     'channel7': 13504.6904297,
#     'channel8': 1.3961852,
#     'channel9': 1.3219837,
#     'channel10': 1.331584,
#     'channel11': 16745.0585938,
#     'channel12': 1.3499177},
#    {'id': 17385270215,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T05:30:00.000+00:00',
#     'utcRange': '2024-05-11T09:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6344416,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7409773,
#     'channel5': 13498.2783203,
#     'channel6': 23167.2089844,
#     'channel7': 13479.8046875,
#     'channel8': 1.407689,
#     'channel9': 1.3223674,
#     'channel10': 1.3384626,
#     'channel11': 16715.0976563,
#     'channel12': 1.356173},
#    {'id': 17385270216,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T05:45:00.000+00:00',
#     'utcRange': '2024-05-11T09:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6604501,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7419395,
#     'channel5': 13510.2587891,
#     'channel6': 23184.875,
#     'channel7': 13489.703125,
#     'channel8': 1.4073582,
#     'channel9': 1.3147999,
#     'channel10': 1.3324513,
#     'channel11': 16728.2792969,
#     'channel12': 1.3515365},
#    {'id': 17385270217,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T06:00:00.000+00:00',
#     'utcRange': '2024-05-11T10:00:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6112902,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.833703,
#     'channel5': 13540.1210938,
#     'channel6': 23231.8671875,
#     'channel7': 13519.3730469,
#     'channel8': 1.397662,
#     'channel9': 1.3225617,
#     'channel10': 1.3318799,
#     'channel11': 16763.7871094,
#     'channel12': 1.3507012},
#    {'id': 17385270218,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T06:15:00.000+00:00',
#     'utcRange': '2024-05-11T10:15:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6551495,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7637491,
#     'channel5': 13498.8710938,
#     'channel6': 23162.7578125,
#     'channel7': 13477.9082031,
#     'channel8': 1.3884095,
#     'channel9': 1.3175172,
#     'channel10': 1.3221136,
#     'channel11': 16713.1777344,
#     'channel12': 1.3426801},
#    {'id': 17385270219,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T06:30:00.000+00:00',
#     'utcRange': '2024-05-11T10:30:00.000+00:00',
#     'principal': True,
#     'channel1': 1.6114707,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7462139,
#     'channel5': 13482.1992188,
#     'channel6': 23132.7382813,
#     'channel7': 13460.8496094,
#     'channel8': 1.3828049,
#     'channel9': 1.3092993,
#     'channel10': 1.316541,
#     'channel11': 16691.9296875,
#     'channel12': 1.3362151},
#    {'id': 17385270220,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T06:45:00.000+00:00',
#     'utcRange': '2024-05-11T10:45:00.000+00:00',
#     'principal': True,
#     'channel1': 1.5149451,
#     'channel2': 0.0,
#     'channel3': 0.0,
#     'channel4': 8.7653561,
#     'channel5': 13479.3535156,
#     'channel6': 23126.9726563,
#     'channel7': 13456.0595703,
#     'channel8': 1.3867925,
#     'channel9': 1.3105843,
#     'channel10': 1.3197182,
#     'channel11': 16687.4628906,
#     'channel12': 1.3390317},
#    {'id': 17385270221,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T07:00:00.000+00:00',
#     'utcRange': '2024-05-11T11:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.4501354,
#     'channel2': 0.0,
#     'channel3': 5.9087248,
#     'channel4': 8.5132246,
#     'channel5': 13476.9111328,
#     'channel6': 23122.2910156,
#     'channel7': 13451.3095703,
#     'channel8': 2.3892744,
#     'channel9': 2.3277869,
#     'channel10': 2.2096589,
#     'channel11': 16683.5039063,
#     'channel12': 2.3089066},
#    {'id': 17385270222,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T07:15:00.000+00:00',
#     'utcRange': '2024-05-11T11:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.0,
#     'channel3': 34.3977699,
#     'channel4': 8.285593,
#     'channel5': 13509.7177734,
#     'channel6': 23178.1386719,
#     'channel7': 13482.3515625,
#     'channel8': 5.8747187,
#     'channel9': 5.7860546,
#     'channel10': 5.5717416,
#     'channel11': 16723.4023438,
#     'channel12': 5.7441716},
#    {'id': 17385270223,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T07:30:00.000+00:00',
#     'utcRange': '2024-05-11T11:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.0,
#     'channel3': 76.254097,
#     'channel4': 8.1244783,
#     'channel5': 13580.5722656,
#     'channel6': 23295.6503906,
#     'channel7': 13546.2939453,
#     'channel8': 11.7119713,
#     'channel9': 11.6159191,
#     'channel10': 11.4147167,
#     'channel11': 16807.5058594,
#     'channel12': 11.5808687},
#    {'id': 17385270224,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T07:45:00.000+00:00',
#     'utcRange': '2024-05-11T11:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.0,
#     'channel3': 160.0905609,
#     'channel4': 7.1982899,
#     'channel5': 13560.3115234,
#     'channel6': 23261.5332031,
#     'channel7': 13521.0849609,
#     'channel8': 23.9220333,
#     'channel9': 23.8170948,
#     'channel10': 23.6652699,
#     'channel11': 16780.9765625,
#     'channel12': 23.801466},
#    {'id': 17385270225,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T08:00:00.000+00:00',
#     'utcRange': '2024-05-11T12:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.0,
#     'channel3': 254.6169739,
#     'channel4': 5.331883,
#     'channel5': 13614.1035156,
#     'channel6': 23348.921875,
#     'channel7': 13566.1289063,
#     'channel8': 37.712574,
#     'channel9': 37.5968285,
#     'channel10': 37.4577408,
#     'channel11': 16843.0507813,
#     'channel12': 37.5890465},
#    {'id': 17385270226,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T08:15:00.000+00:00',
#     'utcRange': '2024-05-11T12:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.0140228,
#     'channel3': 337.7058716,
#     'channel4': 3.0989556,
#     'channel5': 13641.1025391,
#     'channel6': 23391.90625,
#     'channel7': 13585.3095703,
#     'channel8': 49.82724,
#     'channel9': 49.7064476,
#     'channel10': 49.5798378,
#     'channel11': 16872.7734375,
#     'channel12': 49.7045097},
#    {'id': 17385270227,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T08:30:00.000+00:00',
#     'utcRange': '2024-05-11T12:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 0.3624692,
#     'channel3': 411.8395386,
#     'channel4': 1.0320351,
#     'channel5': 13635.9423828,
#     'channel6': 23380.09375,
#     'channel7': 13575.5693359,
#     'channel8': 60.7401657,
#     'channel9': 60.6162453,
#     'channel10': 60.5056,
#     'channel11': 16863.8691406,
#     'channel12': 60.6206703},
#    {'id': 17385270228,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T08:45:00.000+00:00',
#     'utcRange': '2024-05-11T12:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 1.6312013,
#     'channel3': 470.2373352,
#     'channel4': 0.2302261,
#     'channel5': 13643.1533203,
#     'channel6': 23385.5410156,
#     'channel7': 13578.2558594,
#     'channel8': 69.2939835,
#     'channel9': 69.1697693,
#     'channel10': 69.0662231,
#     'channel11': 16868.984375,
#     'channel12': 69.1766586},
#    {'id': 17385270229,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T09:00:00.000+00:00',
#     'utcRange': '2024-05-11T13:00:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 2.7559497,
#     'channel3': 495.1940918,
#     'channel4': 0.1279226,
#     'channel5': 13655.46875,
#     'channel6': 23406.65625,
#     'channel7': 13588.5576172,
#     'channel8': 72.8979492,
#     'channel9': 72.7788239,
#     'channel10': 72.6729965,
#     'channel11': 16883.5605469,
#     'channel12': 72.7832565},
#    {'id': 17385270230,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T09:15:00.000+00:00',
#     'utcRange': '2024-05-11T13:15:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 3.6482213,
#     'channel3': 525.7996216,
#     'channel4': 0.0358937,
#     'channel5': 13669.9169922,
#     'channel6': 23427.2382813,
#     'channel7': 13599.2949219,
#     'channel8': 77.3177872,
#     'channel9': 77.2038956,
#     'channel10': 77.1013565,
#     'channel11': 16898.8164063,
#     'channel12': 77.2076797},
#    {'id': 17385270231,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T09:30:00.000+00:00',
#     'utcRange': '2024-05-11T13:30:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 5.5271297,
#     'channel3': 573.3987427,
#     'channel4': 0.0199157,
#     'channel5': 13629.0195313,
#     'channel6': 23356.5292969,
#     'channel7': 13558.5214844,
#     'channel8': 84.5469131,
#     'channel9': 84.4364853,
#     'channel10': 84.3424149,
#     'channel11': 16848.0234375,
#     'channel12': 84.4419403},
#    {'id': 17385270232,
#     'yearx': 2024,
#     'monthx': 5,
#     'idSoc': 11309,
#     'dateRange': '2024-05-11T09:45:00.000+00:00',
#     'utcRange': '2024-05-11T13:45:00.000+00:00',
#     'principal': True,
#     'channel1': 0.0,
#     'channel2': 7.8773866,
#     'channel3': 624.6202393,
#     'channel4': 0.0,
#     'channel5': 13627.0595703,
#     'channel6': 23352.0898438,
#     'channel7': 13555.7451172,
#     'channel8': 92.1163864,
#     'channel9': 91.9777603,
#     'channel10': 91.9135895,
#     'channel11': 16844.9648438,
#     'channel12': 92.0025787},
#    ...]}]

# %%
# Lista para almacenar las filas del DataFrame
filas_para_df = []

# Iterar sobre los puntos de medición y las fechas en el diccionario
for measure_point, dates_data in data_by_measure_point.items():
    for date, data in dates_data.items():
        for entry in data:
            mediciones = entry.get('measurement', [])
            for medicion in mediciones:
                datos_seleccionados = {
                    'punto_medicion': measure_point,
                    'fecha': date,
                    'year': medicion.get('yearx'),
                    'mes': medicion.get('monthx'),
                    'rango_fecha': medicion.get('dateRange'),
                    'channel3': medicion.get('channel3')
                }
                filas_para_df.append(datos_seleccionados)

df = pd.DataFrame(filas_para_df)

# %%
df
# Out:
#              punto_medicion         fecha  year  mes  \
# 0       URIBE_023_PMGD2_UAS  202405010000  2024    5
# 1       URIBE_023_PMGD2_UAS  202405010000  2024    5
# 2       URIBE_023_PMGD2_UAS  202405010000  2024    5
# 3       URIBE_023_PMGD2_UAS  202405010000  2024    5
# 4       URIBE_023_PMGD2_UAS  202405010000  2024    5
# ...                     ...           ...   ...  ...
# 44155  CURICO_013_PMGD7_LCH  202407010000  2024    7
# 44156  CURICO_013_PMGD7_LCH  202407010000  2024    7
# 44157  CURICO_013_PMGD7_LCH  202407010000  2024    7
# 44158  CURICO_013_PMGD7_LCH  202407010000  2024    7
# 44159  CURICO_013_PMGD7_LCH  202407010000  2024    7
#
#                          rango_fecha  channel3
# 0      2024-05-01T00:00:00.000+00:00       0.0
# 1      2024-05-01T00:15:00.000+00:00       0.0
# 2      2024-05-01T00:30:00.000+00:00       0.0
# 3      2024-05-01T00:45:00.000+00:00       0.0
# 4      2024-05-01T01:00:00.000+00:00       0.0
# ...                              ...       ...
# 44155  2024-07-31T22:45:00.000+00:00       0.0
# 44156  2024-07-31T23:00:00.000+00:00       0.0
# 44157  2024-07-31T23:15:00.000+00:00       0.0
# 44158  2024-07-31T23:30:00.000+00:00       0.0
# 44159  2024-07-31T23:45:00.000+00:00       0.0
#
# [44160 rows x 6 columns]

# %% [markdown]
# #### Entendemos el DF resultante de las consultas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44160 entries, 0 to 44159
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   punto_medicion  44160 non-null  object
#  1   fecha           44160 non-null  object
#  2   year            44160 non-null  int64
#  3   mes             44160 non-null  int64
#  4   rango_fecha     44160 non-null  object
#  5   channel3        44121 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.0+ MB

# %%
#Cambio de fecha a Datetime

df['fecha_DT'] = pd.to_datetime(df['rango_fecha'])

# %%
df['dia'] = df['fecha_DT'].dt.day
df['hora'] = df['fecha_DT'].dt.hour
df['minuto'] = df['fecha_DT'].dt.minute

# %%
#Entender NaN en channel3
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44160 entries, 0 to 44159
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   punto_medicion  44160 non-null  object
#  1   fecha           44160 non-null  object
#  2   year            44160 non-null  int64
#  3   mes             44160 non-null  int64
#  4   rango_fecha     44160 non-null  object
#  5   channel3        44121 non-null  float64
#  6   fecha_DT        44160 non-null  datetime64[ns, UTC]
#  7   dia             44160 non-null  int32
#  8   hora            44160 non-null  int32
#  9   minuto          44160 non-null  int32
# dtypes: datetime64[ns, UTC](1), float64(1), int32(3), int64(2), object(3)
# memory usage: 2.9+ MB

# %%
df[df['channel3'].isna()] #Al ser pocos registros, el problema se identifica directamente con el output. Parece un error en el punto de medicion el dia 2 de julio entre las 8:30 y las 18:00
# Out:
#            punto_medicion         fecha  year  mes  \
# 14818  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14819  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14820  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14821  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14822  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14823  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14824  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14825  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14826  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14827  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14828  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14829  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14830  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14831  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14832  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14833  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14834  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14835  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14836  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14837  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14838  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14839  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14840  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14841  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14842  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14843  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14844  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14845  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14846  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14847  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14848  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14849  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14850  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14851  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14852  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14853  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14854  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14855  TAMANGO_066_B1_IUN  202407010000  2024    7
# 14856  TAMANGO_066_B1_IUN  202407010000  2024    7
#
#                          rango_fecha  channel3                  fecha_DT  dia  \
# 14818  2024-07-02T08:30:00.000+00:00       NaN 2024-07-02 08:30:00+00:00    2
# 14819  2024-07-02T08:45:00.000+00:00       NaN 2024-07-02 08:45:00+00:00    2
# 14820  2024-07-02T09:00:00.000+00:00       NaN 2024-07-02 09:00:00+00:00    2
# 14821  2024-07-02T09:15:00.000+00:00       NaN 2024-07-02 09:15:00+00:00    2
# 14822  2024-07-02T09:30:00.000+00:00       NaN 2024-07-02 09:30:00+00:00    2
# 14823  2024-07-02T09:45:00.000+00:00       NaN 2024-07-02 09:45:00+00:00    2
# 14824  2024-07-02T10:00:00.000+00:00       NaN 2024-07-02 10:00:00+00:00    2
# 14825  2024-07-02T10:15:00.000+00:00       NaN 2024-07-02 10:15:00+00:00    2
# 14826  2024-07-02T10:30:00.000+00:00       NaN 2024-07-02 10:30:00+00:00    2
# 14827  2024-07-02T10:45:00.000+00:00       NaN 2024-07-02 10:45:00+00:00    2
# 14828  2024-07-02T11:00:00.000+00:00       NaN 2024-07-02 11:00:00+00:00    2
# 14829  2024-07-02T11:15:00.000+00:00       NaN 2024-07-02 11:15:00+00:00    2
# 14830  2024-07-02T11:30:00.000+00:00       NaN 2024-07-02 11:30:00+00:00    2
# 14831  2024-07-02T11:45:00.000+00:00       NaN 2024-07-02 11:45:00+00:00    2
# 14832  2024-07-02T12:00:00.000+00:00       NaN 2024-07-02 12:00:00+00:00    2
# 14833  2024-07-02T12:15:00.000+00:00       NaN 2024-07-02 12:15:00+00:00    2
# 14834  2024-07-02T12:30:00.000+00:00       NaN 2024-07-02 12:30:00+00:00    2
# 14835  2024-07-02T12:45:00.000+00:00       NaN 2024-07-02 12:45:00+00:00    2
# 14836  2024-07-02T13:00:00.000+00:00       NaN 2024-07-02 13:00:00+00:00    2
# 14837  2024-07-02T13:15:00.000+00:00       NaN 2024-07-02 13:15:00+00:00    2
# 14838  2024-07-02T13:30:00.000+00:00       NaN 2024-07-02 13:30:00+00:00    2
# 14839  2024-07-02T13:45:00.000+00:00       NaN 2024-07-02 13:45:00+00:00    2
# 14840  2024-07-02T14:00:00.000+00:00       NaN 2024-07-02 14:00:00+00:00    2
# 14841  2024-07-02T14:15:00.000+00:00       NaN 2024-07-02 14:15:00+00:00    2
# 14842  2024-07-02T14:30:00.000+00:00       NaN 2024-07-02 14:30:00+00:00    2
# 14843  2024-07-02T14:45:00.000+00:00       NaN 2024-07-02 14:45:00+00:00    2
# 14844  2024-07-02T15:00:00.000+00:00       NaN 2024-07-02 15:00:00+00:00    2
# 14845  2024-07-02T15:15:00.000+00:00       NaN 2024-07-02 15:15:00+00:00    2
# 14846  2024-07-02T15:30:00.000+00:00       NaN 2024-07-02 15:30:00+00:00    2
# 14847  2024-07-02T15:45:00.000+00:00       NaN 2024-07-02 15:45:00+00:00    2
# 14848  2024-07-02T16:00:00.000+00:00       NaN 2024-07-02 16:00:00+00:00    2
# 14849  2024-07-02T16:15:00.000+00:00       NaN 2024-07-02 16:15:00+00:00    2
# 14850  2024-07-02T16:30:00.000+00:00       NaN 2024-07-02 16:30:00+00:00    2
# 14851  2024-07-02T16:45:00.000+00:00       NaN 2024-07-02 16:45:00+00:00    2
# 14852  2024-07-02T17:00:00.000+00:00       NaN 2024-07-02 17:00:00+00:00    2
# 14853  2024-07-02T17:15:00.000+00:00       NaN 2024-07-02 17:15:00+00:00    2
# 14854  2024-07-02T17:30:00.000+00:00       NaN 2024-07-02 17:30:00+00:00    2
# 14855  2024-07-02T17:45:00.000+00:00       NaN 2024-07-02 17:45:00+00:00    2
# 14856  2024-07-02T18:00:00.000+00:00       NaN 2024-07-02 18:00:00+00:00    2
#
#        hora  minuto
# 14818     8      30
# 14819     8      45
# 14820     9       0
# 14821     9      15
# 14822     9      30
# 14823     9      45
# 14824    10       0
# 14825    10      15
# 14826    10      30
# 14827    10      45
# 14828    11       0
# 14829    11      15
# 14830    11      30
# 14831    11      45
# 14832    12       0
# 14833    12      15
# 14834    12      30
# 14835    12      45
# 14836    13       0
# 14837    13      15
# 14838    13      30
# 14839    13      45
# 14840    14       0
# 14841    14      15
# 14842    14      30
# 14843    14      45
# 14844    15       0
# 14845    15      15
# 14846    15      30
# 14847    15      45
# 14848    16       0
# 14849    16      15
# 14850    16      30
# 14851    16      45
# 14852    17       0
# 14853    17      15
# 14854    17      30
# 14855    17      45
# 14856    18       0

# %%
df.columns
# Out:
# Index(['punto_medicion', 'fecha', 'year', 'mes', 'rango_fecha', 'channel3',
#        'fecha_DT', 'dia', 'hora', 'minuto'],
#       dtype='object')

# %% [markdown]
# #### 3.- Informe en Excel

# %%
#Preparar datos para llevarlos a Excel

# %%
pivot_df = df.pivot_table(
    index=['year', 'mes', 'dia', 'hora', 'minuto'],
    columns='punto_medicion',  
    values='channel3')


pivot_df.reset_index(inplace=True)

# %%
pivot_df.describe()
# Out:
# punto_medicion    year          mes          dia         hora       minuto  \
# count           8832.0  8832.000000  8832.000000  8832.000000  8832.000000
# mean            2024.0     6.000000    15.836957    11.500000    22.500000
# std                0.0     0.820969     8.854728     6.922578    16.771459
# min             2024.0     5.000000     1.000000     0.000000     0.000000
# 25%             2024.0     5.000000     8.000000     5.750000    11.250000
# 50%             2024.0     6.000000    16.000000    11.500000    22.500000
# 75%             2024.0     7.000000    23.250000    17.250000    33.750000
# max             2024.0     7.000000    31.000000    23.000000    45.000000
#
# punto_medicion  CURICO_013_PMGD7_LCH  MALLOCO_012_PMGD5_PNF  \
# count                    8832.000000            8832.000000
# mean                       96.294874              79.931072
# std                       264.489005             140.506259
# min                         0.000000               0.000000
# 25%                         0.000000               0.000000
# 50%                         0.000000               0.000000
# 75%                         0.000000              92.269642
# max                      1530.687622             499.733215
#
# punto_medicion  RENGO_015_PMGD5_SLM  TAMANGO_066_B1_IUN  URIBE_023_PMGD2_UAS
# count                   8832.000000         8793.000000          8832.000000
# mean                     181.417372            5.341466           540.151557
# std                      293.750939            8.451797           752.713606
# min                        0.000000            0.000000             0.000000
# 25%                        0.000000            0.000000             0.000000
# 50%                        0.000000            0.000000             0.000000
# 75%                      268.070785           17.528851          1064.710358
# max                      778.766113           28.576664          2116.407715

# %%
pivot_df.to_excel('Informe_mediciones_puntos.xlsx',index=False) #se crea en la carpeta donde está alojado el notebook
